# %% [markdown]
# # Notebook 4: Efficient Location and Time Series Access Using Polytope Feature Extraction
#
# Notebook 4 showcases efficient geo-location and time series access using polytope feature extraction. By leveraging this feature, we significantly reduce data retrieval from storage, optimizing workflows and resource utilization.

# %% [markdown]
# 1. **Configuring Access to Polytope**

# %%
import os
import dataclasses as dc
from meteodatalab import mars


os.environ["POLYTOPE_USERNAME"] = "admin"
os.environ["POLYTOPE_PASSWORD"] = "xxxxxxxxxxxxxxxxx"
os.environ["POLYTOPE_ADDRESS"] = "https://polytope-dev.mchml.cscs.ch"

# %% [markdown]
# 2. **Selecting geo-location point of interest**

# %%
zrh = mars.Point(47.47, 8.55)

# %% [markdown]
# 3. **Querying the data** <br>
# The `feature` attribute tells polytope to extract **only the relevant data at the given point**.
# The amount of data that is retrieved from storage is signficantly reduced.

# %%
request = mars.Request(
    param="T_2M",
    date="20240222",
    time="0300",
    model=mars.Model.ICON_CH1_EPS,
    levtype=mars.LevType.SURFACE,
    number=1,
    feature=mars.TimeseriesFeature(points=[zrh], end=1440),
)

# %%
from meteodatalab import mch_model_data

ds = mch_model_data.get_from_polytope(request)
# Out:
# 2024-04-25 08:20:23 - INFO - Sending request...
# {'request': 'class: od\n'
#             "date: '20240222'\n"
#             "expver: '0001'\n"
#             'feature:\n'
#             '  end: 1440\n'
#             '  points:\n'
#             '  - - 47.47\n'
#             '    - 8.55\n'
#             '  start: 0\n'
#             '  type: timeseries\n'
#             'levtype: sfc\n'
#             'model: icon-ch1-eps\n'
#             'number: 1\n'
#             "param: '500011'\n"
#             'stream: enfo\n'
#             "time: '0300'\n"
#             'type: ememb\n',
#  'verb': 'retrieve'}
# 2024-04-25 08:20:23 - INFO - Request accepted. Please poll https://polytope-dev.mchml.cscs.ch/api/v1/requests/ebb1c27f-5048-431f-8bbb-716dc7410231 for status
# 2024-04-25 08:20:23 - INFO - Checking request status (ebb1c27f-5048-431f-8bbb-716dc7410231)...
# 2024-04-25 08:20:24 - INFO - The current status of the request is 'queued'
# 2024-04-25 08:20:29 - INFO - The current status of the request is 'processing'
# 2024-04-25 08:20:35 - INFO - The current status of the request is 'processed'

# %% [markdown]
# 4. **Visualizing the data**

# %%
ds["2m Temperature"].plot()

# %% [markdown]
# 5. **Concatenating timeseries**

# %%
# mars.Request is a dataclass
requests = [dc.replace(request, date=str(d), time="0000") for d in range(20240414, 20240425)]
requests
# Out:
# [Request(param='T_2M', date='20240414', time='0000', expver='0001', levelist=None, number=1, step=None, class_=<Class.OPERATIONAL_DATA: 'od'>, levtype='sfc', model='ICON-CH1-EPS', stream='enfo', type='ememb', feature=TimeseriesFeature(type=<FeatureType.TIMESERIES: 'timeseries'>, points=[Point(lat=47.47, lon=8.55)], start=0, end=1440)),
#  Request(param='T_2M', date='20240415', time='0000', expver='0001', levelist=None, number=1, step=None, class_=<Class.OPERATIONAL_DATA: 'od'>, levtype='sfc', model='ICON-CH1-EPS', stream='enfo', type='ememb', feature=TimeseriesFeature(type=<FeatureType.TIMESERIES: 'timeseries'>, points=[Point(lat=47.47, lon=8.55)], start=0, end=1440)),
#  Request(param='T_2M', date='20240416', time='0000', expver='0001', levelist=None, number=1, step=None, class_=<Class.OPERATIONAL_DATA: 'od'>, levtype='sfc', model='ICON-CH1-EPS', stream='enfo', type='ememb', feature=TimeseriesFeature(type=<FeatureType.TIMESERIES: 'timeseries'>, points=[Point(lat=47.47, lon=8.55)], start=0, end=1440)),
#  Request(param='T_2M', date='20240417', time='0000', expver='0001', levelist=None, number=1, step=None, class_=<Class.OPERATIONAL_DATA: 'od'>, levtype='sfc', model='ICON-CH1-EPS', stream='enfo', type='ememb', feature=TimeseriesFeature(type=<FeatureType.TIMESERIES: 'timeseries'>, points=[Point(lat=47.47, lon=8.55)], start=0, end=1440)),
#  Request(param='T_2M', date='20240418', time='0000', expver='0001', levelist=None, number=1, step=None, class_=<Class.OPERATIONAL_DATA: 'od'>, levtype='sfc', model='ICON-CH1-EPS', stream='enfo', type='ememb', feature=TimeseriesFeature(type=<FeatureType.TIMESERIES: 'timeseries'>, points=[Point(lat=47.47, lon=8.55)], start=0, end=1440)),
#  Request(param='T_2M', date='20240419', time='0000', expver='0001', levelist=None, number=1, step=None, class_=<Class.OPERATIONAL_DATA: 'od'>, levtype='sfc', model='ICON-CH1-EPS', stream='enfo', type='ememb', feature=TimeseriesFeature(type=<FeatureType.TIMESERIES: 'timeseries'>, points=[Point(lat=47.47, lon=8.55)], start=0, end=1440)),
#  Request(param='T_2M', date='20240420', time='0000', expver='0001', levelist=None, number=1, step=None, class_=<Class.OPERATIONAL_DATA: 'od'>, levtype='sfc', model='ICON-CH1-EPS', stream='enfo', type='ememb', feature=TimeseriesFeature(type=<FeatureType.TIMESERIES: 'timeseries'>, points=[Point(lat=47.47, lon=8.55)], start=0, end=1440)),
#  Request(param='T_2M', date='20240421', time='0000', expver='0001', levelist=None, number=1, step=None, class_=<Class.OPERATIONAL_DATA: 'od'>, levtype='sfc', model='ICON-CH1-EPS', stream='enfo', type='ememb', feature=TimeseriesFeature(type=<FeatureType.TIMESERIES: 'timeseries'>, points=[Point(lat=47.47, lon=8.55)], start=0, end=1440)),
#  Request(param='T_2M', date='20240422', time='0000', expver='0001', levelist=None, number=1, step=None, class_=<Class.OPERATIONAL_DATA: 'od'>, levtype='sfc', model='ICON-CH1-EPS', stream='enfo', type='ememb', feature=TimeseriesFeature(type=<FeatureType.TIMESERIES: 'timeseries'>, points=[Point(lat=47.47, lon=8.55)], start=0, end=1440)),
#  Request(param='T_2M', date='20240423', time='0000', expver='0001', levelist=None, number=1, step=None, class_=<Class.OPERATIONAL_DATA: 'od'>, levtype='sfc', model='ICON-CH1-EPS', stream='enfo', type='ememb', feature=TimeseriesFeature(type=<FeatureType.TIMESERIES: 'timeseries'>, points=[Point(lat=47.47, lon=8.55)], start=0, end=1440)),
#  Request(param='T_2M', date='20240424', time='0000', expver='0001', levelist=None, number=1, step=None, class_=<Class.OPERATIONAL_DATA: 'od'>, levtype='sfc', model='ICON-CH1-EPS', stream='enfo', type='ememb', feature=TimeseriesFeature(type=<FeatureType.TIMESERIES: 'timeseries'>, points=[Point(lat=47.47, lon=8.55)], start=0, end=1440))]

# %%
from concurrent.futures import ThreadPoolExecutor

import xarray as xr

with ThreadPoolExecutor(max_workers=5) as exec:
    ds = list(exec.map(mch_model_data.get_from_polytope, requests))

t_2m = xr.concat([a["2m Temperature"] for a in ds], dim="t")

t_2m.plot()


# Source: https://nwp-polytope-test.s3.eu-central-2.amazonaws.com/5ddc3f38-2b49-4e49-9f4f-c2287d85e15c
# Out:
# 2024-04-25 08:20:36 - INFO - Sending request...
# {'request': 'class: od\n'
#             "date: '20240414'\n"
#             "expver: '0001'\n"
#             'feature:\n'
#             '  end: 1440\n'
#             '  points:\n'
#             '  - - 47.47\n'
#             '    - 8.55\n'
#             '  start: 0\n'
#             '  type: timeseries\n'
#             'levtype: sfc\n'
#             'model: icon-ch1-eps\n'
#             'number: 1\n'
#             "param: '500011'\n"
#             'stream: enfo\n'
#             "time: '0000'\n"
#             'type: ememb\n',
#  'verb': 'retrieve'}
# 2024-04-25 08:20:36 - INFO - Sending request...
# {'request': 'class: od\n'
#             "date: '20240415'\n"
#             "expver: '0001'\n"
#             'feature:\n'
#             '  end: 1440\n'
#             '  points:\n'
#             '  - - 47.47\n'
#             '    - 8.55\n'
#             '  start: 0\n'
#             '  type: timeseries\n'
#             'levtype: sfc\n'
#             'model: icon-ch1-eps\n'
#             'number: 1\n'
#             "param: '500011'\n"
#             'stream: enfo\n'
#             "time: '0000'\n"
#             'type: ememb\n',
#  'verb': 'retrieve'}
# 2024-04-25 08:20:36 - INFO - Sending request...
# {'request': 'class: od\n'
#             "date: '20240416'\n"
#             "expver: '0001'\n"
#             'feature:\n'
#             '  end: 1440\n'
#             '  points:\n'
#             '  - - 47.47\n'
#             '    - 8.55\n'
#             '  start: 0\n'
#             '  type: timeseries\n'
#             'levtype: sfc\n'
#             'model: icon-ch1-eps\n'
#             'number: 1\n'
#             "param: '500011'\n"
#             'stream: enfo\n'
#             "time: '0000'\n"
#             'type: ememb\n',
#  'verb': 'retrieve'}
# 2024-04-25 08:20:36 - INFO - Sending request...
# {'request': 'class: od\n'
#             "date: '20240417'\n"
#             "expver: '0001'\n"
#             'feature:\n'
#             '  end: 1440\n'
#             '  points:\n'
#             '  - - 47.47\n'
#             '    - 8.55\n'
#             '  start: 0\n'
#             '  type: timeseries\n'
#             'levtype: sfc\n'
#             'model: icon-ch1-eps\n'
#             'number: 1\n'
#             "param: '500011'\n"
#             'stream: enfo\n'
#             "time: '0000'\n"
#             'type: ememb\n',
#  'verb': 'retrieve'}
# 2024-04-25 08:20:36 - INFO - Sending request...
# {'request': 'class: od\n'
#             "date: '20240418'\n"
#             "expver: '0001'\n"
#             'feature:\n'
#             '  end: 1440\n'
#             '  points:\n'
#             '  - - 47.47\n'
#             '    - 8.55\n'
#             '  start: 0\n'
#             '  type: timeseries\n'
#             'levtype: sfc\n'
#             'model: icon-ch1-eps\n'
#             'number: 1\n'
#             "param: '500011'\n"
#             'stream: enfo\n'
#             "time: '0000'\n"
#             'type: ememb\n',
#  'verb': 'retrieve'}
# 2024-04-25 08:20:37 - INFO - Request accepted. Please poll https://polytope-dev.mchml.cscs.ch/api/v1/requests/d0b8a5de-fa84-4b69-8158-0b49a7e1ac38 for status
# 2024-04-25 08:20:37 - INFO - Checking request status (d0b8a5de-fa84-4b69-8158-0b49a7e1ac38)...
# 2024-04-25 08:20:37 - INFO - Request accepted. Please poll https://polytope-dev.mchml.cscs.ch/api/v1/requests/e06f02aa-1e1b-4a36-ae9e-d8b142538e76 for status
# 2024-04-25 08:20:37 - INFO - Checking request status (e06f02aa-1e1b-4a36-ae9e-d8b142538e76)...
# 2024-04-25 08:20:37 - INFO - Request accepted. Please poll https://polytope-dev.mchml.cscs.ch/api/v1/requests/93947a23-0611-4b28-96f9-e3d2b4074607 for status
# 2024-04-25 08:20:37 - INFO - Checking request status (93947a23-0611-4b28-96f9-e3d2b4074607)...
# 2024-04-25 08:20:37 - INFO - Request accepted. Please poll https://polytope-dev.mchml.cscs.ch/api/v1/requests/1a703d66-76c2-4549-869d-caf3f3b1053e for status
# 2024-04-25 08:20:37 - INFO - Checking request status (1a703d66-76c2-4549-869d-caf3f3b1053e)...
# 2024-04-25 08:20:37 - INFO - Request accepted. Please poll https://polytope-dev.mchml.cscs.ch/api/v1/requests/580a8b89-42e3-481f-8e31-f52b28ec32c2 for status
# 2024-04-25 08:20:37 - INFO - Checking request status (580a8b89-42e3-481f-8e31-f52b28ec32c2)...
# 2024-04-25 08:20:37 - INFO - The current status of the request is 'queued'
# 2024-04-25 08:20:37 - INFO - The current status of the request is 'queued'
# 2024-04-25 08:20:37 - INFO - The current status of the request is 'queued'
# 2024-04-25 08:20:37 - INFO - The current status of the request is 'queued'
# 2024-04-25 08:20:37 - INFO - The current status of the request is 'queued'
# 2024-04-25 08:20:39 - INFO - The current status of the request is 'processing'
# 2024-04-25 08:20:39 - INFO - The current status of the request is 'processing'
# 2024-04-25 08:20:44 - INFO - The current status of the request is 'processing'
# 2024-04-25 08:20:44 - INFO - The current status of the request is 'processing'
# 2024-04-25 08:20:44 - INFO - The current status of the request is 'processing'
# 2024-04-25 08:20:44 - INFO - The current status of the request is 'processed'
# 2024-04-25 08:20:45 - INFO - The current status of the request is 'processed'
# 2024-04-25 08:20:45 - INFO - Sending request...
# {'request': 'class: od\n'
#             "date: '20240419'\n"
#             "expver: '0001'\n"
#             'feature:\n'
#             '  end: 1440\n'
#             '  points:\n'
#             '  - - 47.47\n'
#             '    - 8.55\n'
#             '  start: 0\n'
#             '  type: timeseries\n'
#             'levtype: sfc\n'
#             'model: icon-ch1-eps\n'
#             'number: 1\n'
#             "param: '500011'\n"
#             'stream: enfo\n'
#             "time: '0000'\n"
#             'type: ememb\n',
#  'verb': 'retrieve'}
# 2024-04-25 08:20:45 - INFO - Sending request...
# {'request': 'class: od\n'
#             "date: '20240420'\n"
#             "expver: '0001'\n"
#             'feature:\n'
#             '  end: 1440\n'
#             '  points:\n'
#             '  - - 47.47\n'
#             '    - 8.55\n'
#             '  start: 0\n'
#             '  type: timeseries\n'
#             'levtype: sfc\n'
#             'model: icon-ch1-eps\n'
#             'number: 1\n'
#             "param: '500011'\n"
#             'stream: enfo\n'
#             "time: '0000'\n"
#             'type: ememb\n',
#  'verb': 'retrieve'}
# 2024-04-25 08:20:45 - INFO - Request accepted. Please poll https://polytope-dev.mchml.cscs.ch/api/v1/requests/0354feb5-de77-46e6-badc-bc71bd496a2d for status
# 2024-04-25 08:20:45 - INFO - Checking request status (0354feb5-de77-46e6-badc-bc71bd496a2d)...
# 2024-04-25 08:20:45 - INFO - Request accepted. Please poll https://polytope-dev.mchml.cscs.ch/api/v1/requests/d3f557b3-8532-4ee3-a14f-4a87e7b81629 for status
# 2024-04-25 08:20:45 - INFO - Checking request status (d3f557b3-8532-4ee3-a14f-4a87e7b81629)...
# 2024-04-25 08:20:45 - INFO - The current status of the request is 'queued'
# 2024-04-25 08:20:45 - INFO - The current status of the request is 'queued'
# 2024-04-25 08:20:49 - INFO - The current status of the request is 'processed'
# 2024-04-25 08:20:49 - INFO - The current status of the request is 'processed'
# 2024-04-25 08:20:49 - INFO - The current status of the request is 'processed'
# 2024-04-25 08:20:49 - INFO - Sending request...
# {'request': 'class: od\n'
#             "date: '20240421'\n"
#             "expver: '0001'\n"
#             'feature:\n'
#             '  end: 1440\n'
#             '  points:\n'
#             '  - - 47.47\n'
#             '    - 8.55\n'
#             '  start: 0\n'
#             '  type: timeseries\n'
#             'levtype: sfc\n'
#             'model: icon-ch1-eps\n'
#             'number: 1\n'
#             "param: '500011'\n"
#             'stream: enfo\n'
#             "time: '0000'\n"
#             'type: ememb\n',
#  'verb': 'retrieve'}
# 2024-04-25 08:20:49 - INFO - Sending request...
# {'request': 'class: od\n'
#             "date: '20240422'\n"
#             "expver: '0001'\n"
#             'feature:\n'
#             '  end: 1440\n'
#             '  points:\n'
#             '  - - 47.47\n'
#             '    - 8.55\n'
#             '  start: 0\n'
#             '  type: timeseries\n'
#             'levtype: sfc\n'
#             'model: icon-ch1-eps\n'
#             'number: 1\n'
#             "param: '500011'\n"
#             'stream: enfo\n'
#             "time: '0000'\n"
#             'type: ememb\n',
#  'verb': 'retrieve'}
# 2024-04-25 08:20:49 - INFO - Sending request...
# {'request': 'class: od\n'
#             "date: '20240423'\n"
#             "expver: '0001'\n"
#             'feature:\n'
#             '  end: 1440\n'
#             '  points:\n'
#             '  - - 47.47\n'
#             '    - 8.55\n'
#             '  start: 0\n'
#             '  type: timeseries\n'
#             'levtype: sfc\n'
#             'model: icon-ch1-eps\n'
#             'number: 1\n'
#             "param: '500011'\n"
#             'stream: enfo\n'
#             "time: '0000'\n"
#             'type: ememb\n',
#  'verb': 'retrieve'}
# 2024-04-25 08:20:49 - INFO - Request accepted. Please poll https://polytope-dev.mchml.cscs.ch/api/v1/requests/12b1178e-050e-4cea-89c9-286e3db4a3d5 for status
# 2024-04-25 08:20:49 - INFO - Checking request status (12b1178e-050e-4cea-89c9-286e3db4a3d5)...
# 2024-04-25 08:20:49 - INFO - Request accepted. Please poll https://polytope-dev.mchml.cscs.ch/api/v1/requests/90769bd8-d811-4e0e-9daa-c5b744cba06e for status
# 2024-04-25 08:20:49 - INFO - Checking request status (90769bd8-d811-4e0e-9daa-c5b744cba06e)...
# 2024-04-25 08:20:50 - INFO - The current status of the request is 'processing'
# 2024-04-25 08:20:50 - INFO - The current status of the request is 'queued'
# 2024-04-25 08:20:50 - INFO - The current status of the request is 'processing'
# 2024-04-25 08:20:50 - INFO - Request accepted. Please poll https://polytope-dev.mchml.cscs.ch/api/v1/requests/3a1a298f-91e1-4cbc-88b4-40e862f53185 for status
# 2024-04-25 08:20:50 - INFO - Checking request status (3a1a298f-91e1-4cbc-88b4-40e862f53185)...
# 2024-04-25 08:20:50 - INFO - The current status of the request is 'queued'
# 2024-04-25 08:20:50 - INFO - The current status of the request is 'queued'
# 2024-04-25 08:20:55 - INFO - The current status of the request is 'processed'
# 2024-04-25 08:20:55 - INFO - The current status of the request is 'processed'
# 2024-04-25 08:20:56 - INFO - Sending request...
# {'request': 'class: od\n'
#             "date: '20240424'\n"
#             "expver: '0001'\n"
#             'feature:\n'
#             '  end: 1440\n'
#             '  points:\n'
#             '  - - 47.47\n'
#             '    - 8.55\n'
#             '  start: 0\n'
#             '  type: timeseries\n'
#             'levtype: sfc\n'
#             'model: icon-ch1-eps\n'
#             'number: 1\n'
#             "param: '500011'\n"
#             'stream: enfo\n'
#             "time: '0000'\n"
#             'type: ememb\n',
#  'verb': 'retrieve'}
# 2024-04-25 08:20:56 - INFO - Request accepted. Please poll https://polytope-dev.mchml.cscs.ch/api/v1/requests/1de6de76-b2fe-407f-9b24-35f15de25a81 for status
# 2024-04-25 08:20:56 - INFO - Checking request status (1de6de76-b2fe-407f-9b24-35f15de25a81)...
# 2024-04-25 08:20:56 - INFO - The current status of the request is 'queued'
# 2024-04-25 08:21:00 - INFO - The current status of the request is 'processing'
# 2024-04-25 08:21:00 - INFO - The current status of the request is 'processing'
# 2024-04-25 08:21:00 - INFO - The current status of the request is 'processing'
# 2024-04-25 08:21:00 - INFO - The current status of the request is 'processing'
# 2024-04-25 08:21:05 - INFO - The current status of the request is 'processed'
# 2024-04-25 08:21:06 - INFO - The current status of the request is 'processed'
# 2024-04-25 08:21:06 - INFO - The current status of the request is 'processed'
# 2024-04-25 08:21:06 - INFO - The current status of the request is 'processed'
